# %%
from ingest import load_faq_data, build_index
from dotenv import load_dotenv
from openai import OpenAI
from rag_helper import RAGBase
import os

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
load_dotenv()

openai_client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key= os.getenv("GROQ_API_KEY"))

# %%
assistant = RAGBase(index, openai_client)

# %%
assistant.rag("Do I have to pay to participate in the course")
# Out:
# "According to the provided context:\n\n* You do not need to subscribe or pay for the OpenAI API to complete the course homework, as some free alternatives are listed in the course GitHub.\n* While using the OpenAI API itself doesn't cost much and starts at a recharge rate of $5, initial usage might cost as little as 5 cents.\n* You don't need to pay or spend any money to participate in the course. Registration is optional and only serves to gauge interest."
